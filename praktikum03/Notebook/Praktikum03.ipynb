# %%
# Menghubungkan Colab dengan Google Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Memanggil data set lewat gdrive
path = "/content/drive/MyDrive/Praktikum/Data/"

# %%
# Membaca file csv menggunakan pandas
import pandas as pd

df = pd.read_csv(path + 'socr.csv')
df.head()
# Out:
#    Index  Height(Inches)  Weight(Pounds)
# 0      1        65.78331        112.9925
# 1      2        71.51521        136.4873
# 2      3        69.39874        153.0269
# 3      4        68.21660        142.3354
# 4      5        67.78781        144.2971

# %%
# Membaca file csv menggunakan pandas
import pandas as pd

df = pd.read_csv(path + 'stunting_wasting_dataset.csv')
df.head()
# Out:
#   Jenis Kelamin  Umur (bulan)  Tinggi Badan (cm)  Berat Badan (kg)  \
# 0     Laki-laki            19               91.6              13.3
# 1     Laki-laki            20               77.7               8.5
# 2     Laki-laki            10               79.0              10.3
# 3     Perempuan             2               50.3               8.3
# 4     Perempuan             5               56.4              10.9
#
#            Stunting             Wasting
# 0              Tall  Risk of Overweight
# 1           Stunted         Underweight
# 2            Normal  Risk of Overweight
# 3  Severely Stunted  Risk of Overweight
# 4  Severely Stunted  Risk of Overweight

# %%
# !git config --global user.name "Sakiaihara12"
# !git config --global user.email "sakiazaele@gmail"

# %%
# !git add praktikum02 praktikum03 Data Report

# %%
# !git add .

# %%
# %cd /content/drive/MyDrive/Praktikum

# cek status repo, biar tau apa aja yg berubah/baru
# !git status

# add semua perubahan (folder/file baru termasuk praktikum 02)
# !git add .

# commit dengan pesan sesuai
# !git commit -m "Tambah praktikum 02"

# push ke GitHub
# !git push
# Out:
# /content/drive/MyDrive/Praktikum
# On branch main
# Your branch is up to date with 'origin/main'.
#
# Changes to be committed:
#   (use "git restore --staged <file>..." to unstage)
# 	new file:   Data/500_Person_Gender_Height_Weight_Index.csv
# 	new file:   Data/day.csv
# 	new file:   Data/hour.csv
# 	new file:   Data/socr.csv
# 	new file:   Data/stunting_wasting_dataset.csv
# 	new file:   Report/praktikum02_Muhammad Riandana Pranatha_0110224076_ML Pagi.pdf
# 	new file:   praktikum02/Notebook/Untitled0.ipynb
# 	new file:   praktikum03/Praktikum03.ipynb
#
# [main 038b218] Tambah praktikum 02
#  8 files changed, 143617 insertions(+)
#  create mode 100644 Data/500_Person_Gender_Height_Weight_Index.csv
#  create mode 100644 Data/day.csv
#  create mode 100644 Data/hour.csv
#  create mode 100644 Data/socr.csv
#  create mode 100644 Data/stunting_wasting_dataset.csv
#  create mode 100644 Report/praktikum02_Muhammad Riandana Pranatha_0110224076_ML Pagi.pdf
# ...
